# %%
# !pip install -U tensorflow tensorflow_probability

# %%
import tensorflow as tf
import tensorflow_probability as tfp

print(tf.__version__)
# Out:
# 2.7.0

# %%
import random
import gym 
import numpy as np
from collections import deque

# %%
class ReplayBuffer:
    """
    Replay Buffer
    Stores and retrieves gameplay experiences
    """

    def __init__(self):
        self.gameplay_experiences = deque(maxlen=1000000)

    def store_gameplay_experience(self, state, next_state, reward, action,
                                  done):
        """
        Records a single step (state transition) of gameplay experience.
        :param state: the current game state
        :param next_state: the game state after taking action
        :param reward: the reward taking action at the current state brings
        :param action: the action taken at the current state
        :param done: a boolean indicating if the game is finished after
        taking the action
        :return: None
        """
        self.gameplay_experiences.append((state, next_state, reward, action,
                                          done))

    def sample_gameplay_batch(self):
        """
        Samples a batch of gameplay experiences for training.
        :return: a list of gameplay experiences
        """
        batch_size = min(128, len(self.gameplay_experiences))
        sampled_gameplay_batch = random.sample(
            self.gameplay_experiences, batch_size)
        state_batch = []
        next_state_batch = []
        action_batch = []
        reward_batch = []
        done_batch = []
        for gameplay_experience in sampled_gameplay_batch:
            state_batch.append(gameplay_experience[0])
            next_state_batch.append(gameplay_experience[1])
            reward_batch.append(gameplay_experience[2])
            action_batch.append(gameplay_experience[3])
            done_batch.append(gameplay_experience[4])
        return np.array(state_batch), np.array(next_state_batch), np.array(
            action_batch), np.array(reward_batch), np.array(done_batch)

# %%
class DQN_Model(tf.keras.Model):
  ''' input state, output each action's predict Q value'''
  def __init__(self, action_size=2):
    super().__init__()
    self.d1 = tf.keras.layers.Dense(30,activation='relu')
    self.d2 = tf.keras.layers.Dense(30,activation='relu')
    self.out = tf.keras.layers.Dense(action_size, activation='linear')

  def call(self, input_data):
    x = tf.convert_to_tensor(input_data)
    x = self.d1(x)
    x = self.d2(x)
    x = self.out(x)
    return x

# %%
class DQN_Agent:
  def __init__(self):
    self.q_net = DQN_Model()
    self.target_q_net = DQN_Model()
    self.gamma = 0.999
    self.opt = tf.keras.optimizers.Adagrad(learning_rate=0.005)
    self.loss_fn = tf.keras.losses.MeanSquaredError()

  def collect_policy(self,state):
    ''' 
    state: shape=(4,) 
    prob: shape=(1, 2)
    action: shape=(1,)
    '''
    if np.random.random() < 0.05:
        return np.random.randint(0, 2)
    return self.policy(state)

    # prob = self.q_net(tf.reshape(state, [-1, 4]))
    # print("prob:", prob)
    # dist = tfp.distributions.Categorical(probs=prob, dtype=tf.float32)
    # action = dist.sample()
    # print("action:", action)
    # return int(action.numpy()[0])

  def policy(self, state):
    prob = self.q_net(tf.reshape(state, [-1, 4]))
    action = tf.math.argmax(prob, axis=1)
    #print("prob:", prob, "action:", action)
    return int(action.numpy()[0])

  # def a_loss(self,prob, action, reward): 
  #   dist = tfp.distributions.Categorical(probs=prob, dtype=tf.float32)
  #   log_prob = dist.log_prob(action)
  #   loss = -log_prob*reward
  #   return loss 

  def update_target_network(self):
      """
      Updates the current target_q_net with the q_net which brings all the
      training in the q_net to the target_q_net.
      :return: None
      """
      self.target_q_net.set_weights(self.q_net.get_weights())

  def train_single_step(self, states, rewards, actions, next_states, dones):

    step_count = 0
    for state, reward, action, next_state, done in zip(states, rewards, actions, next_states, dones):
      step_count += 1
      with tf.GradientTape() as tape:
        predict_q = self.q_net(np.array([state]), training=True)

        target_q = predict_q
        target_q_val = tf.constant([reward])
        if not done:
          next_q = self.target_q_net(np.array([next_state]))
          max_next_q = tf.reduce_max(next_q, axis=1)
          target_q_val += 0.95 * max_next_q
        #print(done, target_q, [[0, action]], target_q_val)
        # action 对应的 Q 值有loss， 其他action 对应的Q值无loss
        target_q = tf.tensor_scatter_nd_update(target_q, [[0, action]], target_q_val)

        #print("step_count:{} target_q: {}, predict_q:{}".format(step_count, target_q, predict_q))
        loss = self.loss_fn(target_q, predict_q)
      
      grads = tape.gradient(loss, self.q_net.trainable_variables)
      self.opt.apply_gradients(zip(grads, self.q_net.trainable_variables))


  def train(self, states, rewards, actions, next_states, dones):

    #print("train:", states, rewards, actions, next_states, dones)
    #print("actions:", actions)

    action_index = list(zip(range(len(actions)), actions))
    with tf.GradientTape() as tape:
      predict_q = self.q_net(states, training=True) # (batch_size, 2)

      # print("states:", tf.shape(states))
      # print("predict_q:", predict_q)

      target_q = predict_q 
      target_q_val = tf.constant(rewards, dtype=tf.float32)  # (batch_size,)

      next_q = self.target_q_net(next_states)
      #print("next_q:", next_q)

      max_next_q = tf.reduce_max(next_q, axis=1) # (batch_size, 1)
      #print("max_next_q:", max_next_q, "target_q_val:", target_q_val)
      target_q_val += max_next_q * 0.95


      target_q = tf.tensor_scatter_nd_update(target_q, action_index, target_q_val)

      #print(done, target_q, [[0, action]], target_q_val)
      # action 对应的 Q 值有loss， 其他action 对应的Q值无loss
      #target_q = tf.tensor_scatter_nd_update(target_q, [[0, action]], target_q_val)

      #print("target_q: {}, predict_q:{}".format(target_q, predict_q))
      loss = self.loss_fn(target_q, predict_q)
      
    grads = tape.gradient(loss, self.q_net.trainable_variables)
    self.opt.apply_gradients(zip(grads, self.q_net.trainable_variables))
    #print("loss:", loss)
    return loss

# %%
env = gym.make('CartPole-v1')

# %%
ai_agent = DQN_Agent()
buffer = ReplayBuffer()

# %%
def collect_gameplay_experiences(env, agent, buffer):
    """
    Collects gameplay experiences by playing env with the instructions
    produced by agent and stores the gameplay experiences in buffer.
    :param env: the game environment
    :param agent: the DQN agent
    :param buffer: the replay buffer
    :return: None
    """
    state = env.reset()
    done = False
    while not done:
        action = agent.collect_policy(state)
        next_state, reward, done, _ = env.step(action)
        if done:
            reward = -1.0
        buffer.store_gameplay_experience(state, next_state,
                                         reward, action, done)
        state = next_state

# %%
def evaluate_training_result(env, agent):
    """
    Evaluates the performance of the current DQN agent by using it to play a
    few episodes of the game and then calculates the average reward it gets.
    The higher the average reward is the better the DQN agent performs.
    :param env: the game environment
    :param agent: the DQN agent
    :return: average reward across episodes
    """
    total_reward = 0.0
    episodes_to_play = 10
    for i in range(episodes_to_play):
        state = env.reset()
        done = False
        episode_reward = 0.0
        while not done:
            action = agent.policy(state)
            next_state, reward, done, _ = env.step(action)
            episode_reward += reward
            state = next_state
        total_reward += episode_reward
    average_reward = total_reward / episodes_to_play
    return average_reward

# %%
steps = 6000


for s in range(steps):
  
  collect_gameplay_experiences(env, ai_agent, buffer)
  gameplay_experience_batch = buffer.sample_gameplay_batch()
  states, next_states, actions, rewards, dones = gameplay_experience_batch
  #print(gameplay_experience_batch)
  loss = ai_agent.train(states, rewards, actions, next_states, dones)
  avg_reward = evaluate_training_result(env, ai_agent)
  print("step = {}, loss = {}, avg_reward={}".format(s, loss, avg_reward))
  # done = False
  # state = env.reset()
  
  # total_reward = 0
  # episode_count = 0

  # rewards = []
  # states = []
  # actions = []
  # next_states = []
  # dones = []

  # while not done:
  #   #env.render()
  #   action = ai_agent.collect_policy(state)
  #   next_state, reward, done, _ = env.step(action)

  #   states.append(state)
  #   actions.append(action)
  #   rewards.append(reward)
  #   next_states.append(next_state)
  #   dones.append(done)

  #   state = next_state
  #   total_reward += reward
    
  #   if done:
  #     ai_agent.train(states, rewards, actions, next_states, dones)
  #     episode_count += 1
  #     if episode_count % 20 == 0:
  #       ai_agent.update_target_network()
  #     #print("total step for this episord are {}".format(t))
  #     print("total reward after {} steps is {}".format(s, total_reward))
# Out:
# step = 0, loss = 0.10644170641899109, avg_reward=9.6
# step = 1, loss = 0.10364633798599243, avg_reward=9.3
# step = 2, loss = 0.08234547823667526, avg_reward=9.3
# step = 3, loss = 0.14284659922122955, avg_reward=9.7
# step = 4, loss = 0.10925962030887604, avg_reward=9.3
# step = 5, loss = 0.16830024123191833, avg_reward=9.5
# step = 6, loss = 0.1353081464767456, avg_reward=8.9
# step = 7, loss = 0.16609293222427368, avg_reward=9.6
# step = 8, loss = 0.13902956247329712, avg_reward=9.4
# step = 9, loss = 0.12115225195884705, avg_reward=9.5
# step = 10, loss = 0.11307188868522644, avg_reward=9.1
# step = 11, loss = 0.10337039083242416, avg_reward=9.6
# step = 12, loss = 0.07457363605499268, avg_reward=9.4
# step = 13, loss = 0.07995116710662842, avg_reward=9.1
# step = 14, loss = 0.12051858007907867, avg_reward=9.5
# step = 15, loss = 0.1015283614397049, avg_reward=9.2
# step = 16, loss = 0.08184604346752167, avg_reward=9.0
# step = 17, loss = 0.09789541363716125, avg_reward=9.7
# step = 18, loss = 0.1083342507481575, avg_reward=9.6
# step = 19, loss = 0.13089340925216675, avg_reward=9.8
# step = 20, loss = 0.12508825957775116, avg_reward=9.3
# step = 21, loss = 0.09424722194671631, avg_reward=9.5
# step = 22, loss = 0.08516526967287064, avg_reward=9.2
# step = 23, loss = 0.1265697181224823, avg_reward=9.0
# step = 24, loss = 0.10170234739780426, avg_reward=9.5
# step = 25, loss = 0.11307002604007721, avg_reward=9.7
# step = 26, loss = 0.1127493679523468, avg_reward=9.0
# step = 27, loss = 0.11763782799243927, avg_reward=9.6
# step = 28, loss = 0.15380704402923584, avg_reward=9.6
# step = 29, loss = 0.12866121530532837, avg_reward=9.4
# step = 30, loss = 0.10211914032697678, avg_reward=9.5
# step = 31, loss = 0.07573291659355164, avg_reward=9.6
# step = 32, loss = 0.14261707663536072, avg_reward=9.3
# step = 33, loss = 0.08940110355615616, avg_reward=9.3
# step = 34, loss = 0.13352936506271362, avg_reward=9.2
# step = 35, loss = 0.10748211294412613, avg_reward=9.0
# step = 36, loss = 0.10379980504512787, avg_reward=9.6
# step = 37, loss = 0.13849645853042603, avg_reward=9.0
# step = 38, loss = 0.08965222537517548, avg_reward=9.0
# step = 39, loss = 0.101393923163414, avg_reward=9.8
# step = 40, loss = 0.12697969377040863, avg_reward=9.4
# step = 41, loss = 0.09239719808101654, avg_reward=9.5
# step = 42, loss = 0.12631100416183472, avg_reward=9.1
# step = 43, loss = 0.12705062329769135, avg_reward=9.2
# step = 44, loss = 0.10421175509691238, avg_reward=9.1
# step = 45, loss = 0.1720549315214157, avg_reward=9.5
# step = 46, loss = 0.12613481283187866, avg_reward=9.4
# step = 47, loss = 0.14586375653743744, avg_reward=9.9
# step = 48, loss = 0.16283991932868958, avg_reward=9.6
# step = 49, loss = 0.11246339976787567, avg_reward=9.4
# step = 50, loss = 0.14000694453716278, avg_reward=9.4
# step = 51, loss = 0.1184406653046608, avg_reward=9.4
# step = 52, loss = 0.14960840344429016, avg_reward=9.7
# step = 53, loss = 0.09322430193424225, avg_reward=9.2
# step = 54, loss = 0.13978376984596252, avg_reward=9.4
# step = 55, loss = 0.11710262298583984, avg_reward=9.3
# step = 56, loss = 0.16146069765090942, avg_reward=9.1
# step = 57, loss = 0.14140361547470093, avg_reward=9.1
# step = 58, loss = 0.13788636028766632, avg_reward=9.3
# step = 59, loss = 0.10454650968313217, avg_reward=9.9
# step = 60, loss = 0.09635169804096222, avg_reward=9.7
# step = 61, loss = 0.08951253443956375, avg_reward=9.1
# step = 62, loss = 0.11054316908121109, avg_reward=9.3
# step = 63, loss = 0.09968537092208862, avg_reward=9.5
# step = 64, loss = 0.0944715142250061, avg_reward=9.2
# step = 65, loss = 0.16047203540802002, avg_reward=9.3
# step = 66, loss = 0.12854978442192078, avg_reward=9.2
# step = 67, loss = 0.09899097681045532, avg_reward=9.4
# step = 68, loss = 0.13674981892108917, avg_reward=9.6
# step = 69, loss = 0.11555871367454529, avg_reward=9.5
# step = 70, loss = 0.09962338209152222, avg_reward=9.4
# step = 71, loss = 0.10888256132602692, avg_reward=9.2
# step = 72, loss = 0.12464652955532074, avg_reward=9.2
# step = 73, loss = 0.10009078681468964, avg_reward=9.3
# step = 74, loss = 0.14667794108390808, avg_reward=9.4
# step = 75, loss = 0.12541696429252625, avg_reward=9.1
# step = 76, loss = 0.08968836069107056, avg_reward=9.3
# step = 77, loss = 0.12176869064569473, avg_reward=9.6
# step = 78, loss = 0.10618076473474503, avg_reward=8.9
# step = 79, loss = 0.11560855805873871, avg_reward=9.6
# step = 80, loss = 0.11091919988393784, avg_reward=9.4
# step = 81, loss = 0.08139750361442566, avg_reward=9.2
# step = 82, loss = 0.08220848441123962, avg_reward=9.9
# step = 83, loss = 0.12075057625770569, avg_reward=9.5
# step = 84, loss = 0.12435080111026764, avg_reward=9.0
# step = 85, loss = 0.14071905612945557, avg_reward=9.5
# step = 86, loss = 0.10710838437080383, avg_reward=9.6
# step = 87, loss = 0.1188361644744873, avg_reward=9.3
# step = 88, loss = 0.12798771262168884, avg_reward=9.5
# step = 89, loss = 0.11232206225395203, avg_reward=9.5
# step = 90, loss = 0.10095255821943283, avg_reward=9.1
# step = 91, loss = 0.07717660069465637, avg_reward=9.2
# step = 92, loss = 0.11227783560752869, avg_reward=9.4
# step = 93, loss = 0.12351777404546738, avg_reward=9.2
# step = 94, loss = 0.12620165944099426, avg_reward=9.0
# step = 95, loss = 0.11451098322868347, avg_reward=9.2
# step = 96, loss = 0.12912017107009888, avg_reward=9.1
# step = 97, loss = 0.10079687833786011, avg_reward=9.8
# step = 98, loss = 0.0901506319642067, avg_reward=9.4
# step = 99, loss = 0.11974687874317169, avg_reward=9.4
# step = 100, loss = 0.11632448434829712, avg_reward=9.2
# step = 101, loss = 0.1107899397611618, avg_reward=9.5
# step = 102, loss = 0.14744490385055542, avg_reward=9.4
# step = 103, loss = 0.10908710211515427, avg_reward=9.3
# step = 104, loss = 0.0821569561958313, avg_reward=9.7
# step = 105, loss = 0.12166852504014969, avg_reward=9.5
# step = 106, loss = 0.12990489602088928, avg_reward=9.4
# step = 107, loss = 0.1066657155752182, avg_reward=9.1
# step = 108, loss = 0.11038337647914886, avg_reward=9.4
# step = 109, loss = 0.13778147101402283, avg_reward=9.4
# step = 110, loss = 0.13980913162231445, avg_reward=9.5
# step = 111, loss = 0.12985821068286896, avg_reward=9.5
# step = 112, loss = 0.11411656439304352, avg_reward=8.9
# step = 113, loss = 0.09685038030147552, avg_reward=9.6
# step = 114, loss = 0.13148191571235657, avg_reward=9.2
# step = 115, loss = 0.11561897397041321, avg_reward=9.6
# step = 116, loss = 0.1182645931839943, avg_reward=9.2
# step = 117, loss = 0.09472140669822693, avg_reward=9.2
# step = 118, loss = 0.11487379670143127, avg_reward=9.2
# step = 119, loss = 0.12160033732652664, avg_reward=9.1
# step = 120, loss = 0.15839603543281555, avg_reward=9.1
# step = 121, loss = 0.12792664766311646, avg_reward=9.5
# step = 122, loss = 0.1463860422372818, avg_reward=9.4
# step = 123, loss = 0.11775832623243332, avg_reward=9.2
# step = 124, loss = 0.13854362070560455, avg_reward=9.1
# step = 125, loss = 0.11542772501707077, avg_reward=9.3
# step = 126, loss = 0.11024157702922821, avg_reward=9.5
# step = 127, loss = 0.1239890456199646, avg_reward=9.3
# step = 128, loss = 0.1163310557603836, avg_reward=9.4
# step = 129, loss = 0.1278197467327118, avg_reward=9.4
# step = 130, loss = 0.10526038706302643, avg_reward=9.2
# step = 131, loss = 0.11746403574943542, avg_reward=9.1
# step = 132, loss = 0.10997758060693741, avg_reward=9.1
# step = 133, loss = 0.12838979065418243, avg_reward=9.5
# step = 134, loss = 0.12656207382678986, avg_reward=9.6
# step = 135, loss = 0.12936930358409882, avg_reward=9.5
# step = 136, loss = 0.10972387343645096, avg_reward=9.6
# step = 137, loss = 0.11887539178133011, avg_reward=9.5
# step = 138, loss = 0.1433417797088623, avg_reward=9.5
# step = 139, loss = 0.1176878958940506, avg_reward=9.3
# step = 140, loss = 0.1014772430062294, avg_reward=9.4
# step = 141, loss = 0.08851689100265503, avg_reward=9.4
# step = 142, loss = 0.11369360983371735, avg_reward=9.6
# step = 143, loss = 0.11642661690711975, avg_reward=9.4
# step = 144, loss = 0.10504651069641113, avg_reward=9.8
# step = 145, loss = 0.13951492309570312, avg_reward=9.2
# step = 146, loss = 0.13246417045593262, avg_reward=9.1
# step = 147, loss = 0.09444962441921234, avg_reward=9.3
# step = 148, loss = 0.093508780002594, avg_reward=9.3
# step = 149, loss = 0.10681037604808807, avg_reward=9.6
# step = 150, loss = 0.11113429814577103, avg_reward=9.2
# step = 151, loss = 0.15242861211299896, avg_reward=9.3
# step = 152, loss = 0.12416444718837738, avg_reward=9.4
# step = 153, loss = 0.12211507558822632, avg_reward=9.1
# step = 154, loss = 0.07956090569496155, avg_reward=9.4
# step = 155, loss = 0.09601777791976929, avg_reward=9.4
# step = 156, loss = 0.10465483367443085, avg_reward=9.6
# step = 157, loss = 0.10456760227680206, avg_reward=9.4
# step = 158, loss = 0.11746510863304138, avg_reward=9.4
# step = 159, loss = 0.1670965552330017, avg_reward=9.6
# step = 160, loss = 0.12422094494104385, avg_reward=9.3
# step = 161, loss = 0.10273565351963043, avg_reward=9.7
# step = 162, loss = 0.11487928032875061, avg_reward=9.1
# step = 163, loss = 0.13329964876174927, avg_reward=9.5
# step = 164, loss = 0.1142309159040451, avg_reward=8.9
# step = 165, loss = 0.13428422808647156, avg_reward=9.4
# step = 166, loss = 0.1128523200750351, avg_reward=9.2
# step = 167, loss = 0.13104572892189026, avg_reward=9.5
# step = 168, loss = 0.1281997263431549, avg_reward=9.1
# step = 169, loss = 0.08239760249853134, avg_reward=8.9
# step = 170, loss = 0.14221128821372986, avg_reward=9.4
# step = 171, loss = 0.09834019839763641, avg_reward=9.5
# step = 172, loss = 0.13027767837047577, avg_reward=9.5
# step = 173, loss = 0.11029490828514099, avg_reward=9.6
# step = 174, loss = 0.1225607693195343, avg_reward=9.3
# step = 175, loss = 0.10830086469650269, avg_reward=9.1
# step = 176, loss = 0.12215283513069153, avg_reward=9.6
# step = 177, loss = 0.1285116970539093, avg_reward=9.2
# step = 178, loss = 0.11605093628168106, avg_reward=8.9
# step = 179, loss = 0.09788466989994049, avg_reward=9.6
# step = 180, loss = 0.10667593777179718, avg_reward=9.2
# step = 181, loss = 0.13692349195480347, avg_reward=9.5
# step = 182, loss = 0.09786175936460495, avg_reward=9.4
# step = 183, loss = 0.11550477147102356, avg_reward=9.3
# step = 184, loss = 0.12339846044778824, avg_reward=9.7
# step = 185, loss = 0.1444512903690338, avg_reward=9.4
# step = 186, loss = 0.13787439465522766, avg_reward=9.6
# step = 187, loss = 0.10414817929267883, avg_reward=9.1
# step = 188, loss = 0.10904095321893692, avg_reward=8.8
# step = 345, loss = 0.1368764042854309, avg_reward=8.7
# step = 346, loss = 0.1006297916173935, avg_reward=9.2
# step = 347, loss = 0.11578382551670074, avg_reward=9.7
# step = 348, loss = 0.1271016001701355, avg_reward=9.3
# step = 349, loss = 0.16048988699913025, avg_reward=9.4
# step = 350, loss = 0.08862219750881195, avg_reward=9.1
# step = 351, loss = 0.14559587836265564, avg_reward=9.3
# step = 352, loss = 0.09835889935493469, avg_reward=8.8
# step = 353, loss = 0.10831134021282196, avg_reward=10.0
# step = 354, loss = 0.12980589270591736, avg_reward=9.3
# step = 355, loss = 0.07834618538618088, avg_reward=9.6
# step = 356, loss = 0.11192987114191055, avg_reward=9.5
# step = 357, loss = 0.12031181156635284, avg_reward=9.6
# step = 358, loss = 0.11674800515174866, avg_reward=9.6
# step = 359, loss = 0.10770637542009354, avg_reward=9.8
# step = 360, loss = 0.12230236083269119, avg_reward=9.3
# step = 361, loss = 0.10953058302402496, avg_reward=9.5
# step = 362, loss = 0.14376211166381836, avg_reward=9.6
# step = 363, loss = 0.11324578523635864, avg_reward=9.1
# step = 364, loss = 0.1352987289428711, avg_reward=9.5
# step = 365, loss = 0.10158000886440277, avg_reward=9.2
# step = 366, loss = 0.13383136689662933, avg_reward=9.8
# step = 367, loss = 0.12695889174938202, avg_reward=9.4
# step = 368, loss = 0.12114155292510986, avg_reward=9.7
# step = 369, loss = 0.12177279591560364, avg_reward=9.0
# step = 370, loss = 0.13815398514270782, avg_reward=9.0
# step = 371, loss = 0.08832107484340668, avg_reward=9.1
# step = 372, loss = 0.12958450615406036, avg_reward=9.7
# step = 373, loss = 0.07609454542398453, avg_reward=9.7
# step = 374, loss = 0.12235751748085022, avg_reward=9.0
# step = 375, loss = 0.14598560333251953, avg_reward=9.2
# step = 376, loss = 0.11724002659320831, avg_reward=9.4
# step = 377, loss = 0.10636746883392334, avg_reward=9.4
# step = 378, loss = 0.08467181771993637, avg_reward=9.5
# step = 379, loss = 0.06656088680028915, avg_reward=9.4
# step = 380, loss = 0.10979487001895905, avg_reward=9.1
# step = 381, loss = 0.0941111296415329, avg_reward=9.2
# step = 382, loss = 0.12740036845207214, avg_reward=8.9
# step = 383, loss = 0.09568953514099121, avg_reward=9.5
# step = 384, loss = 0.13686786592006683, avg_reward=9.2
# step = 385, loss = 0.09322740137577057, avg_reward=9.3
# step = 386, loss = 0.11775720119476318, avg_reward=9.4
# step = 387, loss = 0.11368733644485474, avg_reward=9.2
# step = 388, loss = 0.11834906041622162, avg_reward=9.2
# step = 389, loss = 0.11485350131988525, avg_reward=9.2
# step = 390, loss = 0.13001814484596252, avg_reward=9.4
# step = 391, loss = 0.07729202508926392, avg_reward=9.6
# step = 392, loss = 0.12010909616947174, avg_reward=9.5
# step = 393, loss = 0.09431779384613037, avg_reward=9.5
# step = 394, loss = 0.10747584700584412, avg_reward=9.3
# step = 395, loss = 0.09792942553758621, avg_reward=9.2
# step = 396, loss = 0.1416759043931961, avg_reward=9.3
# step = 397, loss = 0.10942114144563675, avg_reward=9.5
# step = 398, loss = 0.11765727400779724, avg_reward=9.6
# step = 399, loss = 0.1003124937415123, avg_reward=9.3
# step = 400, loss = 0.10441382229328156, avg_reward=9.2
# step = 401, loss = 0.10766194760799408, avg_reward=9.3
# step = 402, loss = 0.1314927339553833, avg_reward=9.0
# step = 403, loss = 0.10927297174930573, avg_reward=8.7
# step = 404, loss = 0.10051368176937103, avg_reward=9.8
# step = 405, loss = 0.12520137429237366, avg_reward=9.3
# step = 406, loss = 0.11660723388195038, avg_reward=9.6
# step = 407, loss = 0.13299469649791718, avg_reward=9.4
# step = 408, loss = 0.11855227500200272, avg_reward=9.5
# step = 409, loss = 0.13292670249938965, avg_reward=9.4
# step = 410, loss = 0.10687270015478134, avg_reward=9.0
# step = 411, loss = 0.1190221756696701, avg_reward=8.9
# step = 412, loss = 0.11478587985038757, avg_reward=9.7
# step = 413, loss = 0.1120542511343956, avg_reward=9.4
# step = 414, loss = 0.1090896874666214, avg_reward=9.3
# step = 415, loss = 0.12773559987545013, avg_reward=9.2
# step = 416, loss = 0.08991082012653351, avg_reward=9.1
# step = 417, loss = 0.13685274124145508, avg_reward=9.3
# step = 418, loss = 0.10373029112815857, avg_reward=9.5
# step = 419, loss = 0.10055236518383026, avg_reward=9.7
# step = 420, loss = 0.15399006009101868, avg_reward=9.7
# step = 421, loss = 0.10102963447570801, avg_reward=9.0
# step = 422, loss = 0.09847746789455414, avg_reward=9.5
# step = 423, loss = 0.14298701286315918, avg_reward=9.2
# step = 424, loss = 0.09393540024757385, avg_reward=9.7
# step = 425, loss = 0.1449277549982071, avg_reward=9.2
# step = 426, loss = 0.11694462597370148, avg_reward=9.5
# step = 427, loss = 0.10613273084163666, avg_reward=9.5
# step = 428, loss = 0.10002128034830093, avg_reward=9.1
# step = 429, loss = 0.07439904659986496, avg_reward=9.3
# step = 430, loss = 0.14644724130630493, avg_reward=9.6
# step = 431, loss = 0.09867753088474274, avg_reward=9.4
# step = 432, loss = 0.11148190498352051, avg_reward=8.9
# step = 433, loss = 0.08592592924833298, avg_reward=9.6
# step = 434, loss = 0.1480419933795929, avg_reward=9.0
# step = 435, loss = 0.14090260863304138, avg_reward=9.0
# step = 436, loss = 0.101921945810318, avg_reward=9.1
# step = 437, loss = 0.09854135662317276, avg_reward=9.1
# step = 438, loss = 0.10276496410369873, avg_reward=9.4
# step = 439, loss = 0.136443093419075, avg_reward=9.4
# step = 440, loss = 0.12627990543842316, avg_reward=9.6
# step = 441, loss = 0.11236203461885452, avg_reward=9.3
# step = 442, loss = 0.07579727470874786, avg_reward=9.2
# step = 443, loss = 0.1358303278684616, avg_reward=9.3
# step = 444, loss = 0.10039550065994263, avg_reward=9.3
# step = 445, loss = 0.06265947222709656, avg_reward=9.6
# step = 446, loss = 0.09136420488357544, avg_reward=9.5
# step = 447, loss = 0.14977918565273285, avg_reward=9.2
# step = 448, loss = 0.12843945622444153, avg_reward=9.4
# step = 449, loss = 0.12828703224658966, avg_reward=9.2
# step = 711, loss = 0.11752185970544815, avg_reward=9.4
# step = 712, loss = 0.10955914855003357, avg_reward=9.8
# step = 713, loss = 0.08283012360334396, avg_reward=9.0
# step = 714, loss = 0.10051178932189941, avg_reward=9.3
# step = 715, loss = 0.11689427495002747, avg_reward=9.2
# step = 716, loss = 0.06822614371776581, avg_reward=9.5
# step = 717, loss = 0.09992430359125137, avg_reward=9.4
# step = 718, loss = 0.1473332792520523, avg_reward=9.5
# step = 719, loss = 0.09502506256103516, avg_reward=9.5
# step = 720, loss = 0.09470219165086746, avg_reward=9.8
# step = 721, loss = 0.08449996262788773, avg_reward=9.7
# step = 722, loss = 0.1307392120361328, avg_reward=9.5
# step = 723, loss = 0.09422504901885986, avg_reward=9.3
# step = 724, loss = 0.09395264089107513, avg_reward=9.1
# step = 725, loss = 0.1187257468700409, avg_reward=9.5
# step = 726, loss = 0.11144566535949707, avg_reward=9.3
# step = 727, loss = 0.11168688535690308, avg_reward=9.5
# step = 728, loss = 0.11218345910310745, avg_reward=9.2
# step = 729, loss = 0.11378146708011627, avg_reward=9.2
# step = 730, loss = 0.10482136905193329, avg_reward=9.5
# step = 731, loss = 0.11121585965156555, avg_reward=9.3
# step = 732, loss = 0.09870024770498276, avg_reward=9.3
# step = 733, loss = 0.10838243365287781, avg_reward=9.2
# step = 734, loss = 0.12628063559532166, avg_reward=9.2
# step = 735, loss = 0.08083963394165039, avg_reward=9.3
# step = 736, loss = 0.11150898039340973, avg_reward=9.0
# step = 737, loss = 0.11530007421970367, avg_reward=9.6
# step = 738, loss = 0.12828730046749115, avg_reward=9.2
# step = 739, loss = 0.1079026311635971, avg_reward=8.9
# step = 740, loss = 0.08269132673740387, avg_reward=9.4
# step = 741, loss = 0.09694681316614151, avg_reward=9.6
# step = 742, loss = 0.10831102728843689, avg_reward=8.7
# step = 743, loss = 0.10272236913442612, avg_reward=9.4
# step = 744, loss = 0.12803417444229126, avg_reward=9.0
# step = 745, loss = 0.11850424855947495, avg_reward=9.2
# step = 746, loss = 0.08718177676200867, avg_reward=9.3
# step = 747, loss = 0.14043226838111877, avg_reward=9.3
# step = 748, loss = 0.11111488938331604, avg_reward=9.5
# step = 749, loss = 0.10962112247943878, avg_reward=9.1
# step = 750, loss = 0.10071159899234772, avg_reward=9.4
# step = 751, loss = 0.07466572523117065, avg_reward=9.3
# step = 752, loss = 0.1284674108028412, avg_reward=9.3
# step = 753, loss = 0.09347864985466003, avg_reward=9.3
# step = 754, loss = 0.1264217346906662, avg_reward=9.6
# step = 755, loss = 0.1269037425518036, avg_reward=9.3
# step = 756, loss = 0.09089799970388412, avg_reward=9.1
# step = 757, loss = 0.10208328068256378, avg_reward=9.1
# step = 758, loss = 0.07702655345201492, avg_reward=9.6
# step = 759, loss = 0.12758460640907288, avg_reward=9.3
# step = 760, loss = 0.08728550374507904, avg_reward=9.0
# step = 761, loss = 0.09179273247718811, avg_reward=9.0
# step = 762, loss = 0.10797541588544846, avg_reward=9.2
# step = 763, loss = 0.10461816936731339, avg_reward=9.0
# step = 764, loss = 0.10874302685260773, avg_reward=9.5
# step = 765, loss = 0.12577281892299652, avg_reward=9.3
# step = 766, loss = 0.1225944310426712, avg_reward=8.9
# step = 767, loss = 0.16096249222755432, avg_reward=9.3
# step = 768, loss = 0.08757016062736511, avg_reward=9.5
# step = 769, loss = 0.11881246417760849, avg_reward=9.2
# step = 770, loss = 0.12561878561973572, avg_reward=9.0
# step = 771, loss = 0.08647572249174118, avg_reward=9.4
# step = 772, loss = 0.10189509391784668, avg_reward=9.4
# step = 773, loss = 0.11771826446056366, avg_reward=9.6
# step = 774, loss = 0.09165340662002563, avg_reward=9.5
# step = 775, loss = 0.0938616544008255, avg_reward=9.7
# step = 776, loss = 0.12382534891366959, avg_reward=9.4
# step = 777, loss = 0.11936081200838089, avg_reward=9.6
# step = 778, loss = 0.1085408553481102, avg_reward=9.7
# step = 779, loss = 0.11042478680610657, avg_reward=9.5
# step = 780, loss = 0.1413329839706421, avg_reward=9.0
# step = 781, loss = 0.1338619440793991, avg_reward=9.2
# step = 782, loss = 0.10748528689146042, avg_reward=9.2
# step = 783, loss = 0.10024464130401611, avg_reward=9.4
# step = 784, loss = 0.11461052298545837, avg_reward=9.3
# step = 785, loss = 0.1077960878610611, avg_reward=9.2
# step = 786, loss = 0.1206340342760086, avg_reward=8.9
# step = 787, loss = 0.0901992917060852, avg_reward=9.7
# step = 788, loss = 0.11848795413970947, avg_reward=9.5
# step = 789, loss = 0.15415993332862854, avg_reward=9.1
# step = 790, loss = 0.09855986386537552, avg_reward=8.8
# step = 791, loss = 0.08855471014976501, avg_reward=8.9
# step = 792, loss = 0.11130741983652115, avg_reward=9.3
# step = 793, loss = 0.11587236076593399, avg_reward=9.0
# step = 794, loss = 0.10790251195430756, avg_reward=9.7
# step = 795, loss = 0.11102043092250824, avg_reward=9.0
# step = 796, loss = 0.1051948070526123, avg_reward=9.5
# step = 797, loss = 0.10873113572597504, avg_reward=9.0
# step = 798, loss = 0.06697791814804077, avg_reward=8.9
# step = 799, loss = 0.07461529225111008, avg_reward=9.3
# step = 800, loss = 0.09761752933263779, avg_reward=9.2
# step = 801, loss = 0.11385801434516907, avg_reward=9.3
# step = 802, loss = 0.12200412899255753, avg_reward=9.1
# step = 803, loss = 0.10262062400579453, avg_reward=9.4
# step = 804, loss = 0.10970704257488251, avg_reward=9.4
# step = 805, loss = 0.10718096792697906, avg_reward=8.9
# step = 806, loss = 0.10075920820236206, avg_reward=9.1
# step = 807, loss = 0.10162428021430969, avg_reward=9.3
# step = 808, loss = 0.0832856148481369, avg_reward=9.5
# step = 809, loss = 0.10241102427244186, avg_reward=9.3
# step = 810, loss = 0.0975348949432373, avg_reward=9.3
# step = 811, loss = 0.1054595410823822, avg_reward=9.3
# step = 812, loss = 0.0954849123954773, avg_reward=9.3
# step = 813, loss = 0.11331812292337418, avg_reward=9.5
# step = 814, loss = 0.12117820978164673, avg_reward=9.2
# step = 815, loss = 0.10734497010707855, avg_reward=9.2
# step = 868, loss = 0.08673309534788132, avg_reward=9.2
# step = 869, loss = 0.10490667819976807, avg_reward=9.6
# step = 870, loss = 0.10504264384508133, avg_reward=9.5
# step = 871, loss = 0.09635374695062637, avg_reward=9.2
# step = 872, loss = 0.11516760289669037, avg_reward=9.6
# step = 873, loss = 0.08396627008914948, avg_reward=9.5
# step = 874, loss = 0.13496583700180054, avg_reward=9.4
# step = 875, loss = 0.13820531964302063, avg_reward=9.1
# step = 876, loss = 0.11181685328483582, avg_reward=9.1
# ...
# step = 5335, loss = 0.052222076803445816, avg_reward=56.8
# step = 5336, loss = 0.05867932364344597, avg_reward=57.5
# step = 5337, loss = 0.02317587286233902, avg_reward=61.3
# step = 5338, loss = 0.027301844209432602, avg_reward=79.9
# step = 5339, loss = 0.029066359624266624, avg_reward=64.2
# step = 5340, loss = 0.009981196373701096, avg_reward=63.7
# step = 5341, loss = 0.04518488422036171, avg_reward=62.3
# step = 5342, loss = 0.018896136432886124, avg_reward=60.2
# step = 5343, loss = 0.043929412961006165, avg_reward=70.0
# step = 5344, loss = 0.053205519914627075, avg_reward=59.4
# step = 5345, loss = 0.06693477928638458, avg_reward=55.6
# step = 5346, loss = 0.018329475075006485, avg_reward=64.2
# step = 5347, loss = 0.030223730951547623, avg_reward=62.6
# step = 5348, loss = 0.03176580369472504, avg_reward=68.8
# step = 5349, loss = 0.04006052017211914, avg_reward=69.2
# step = 5350, loss = 0.028117096051573753, avg_reward=65.0
# step = 5351, loss = 0.056740958243608475, avg_reward=61.2
# step = 5352, loss = 0.08453536778688431, avg_reward=59.2
# step = 5353, loss = 0.04915472865104675, avg_reward=68.2
# step = 5354, loss = 0.054878003895282745, avg_reward=74.8
# step = 5355, loss = 0.03965810686349869, avg_reward=63.9
# step = 5356, loss = 0.049688614904880524, avg_reward=64.0
# step = 5357, loss = 0.026776842772960663, avg_reward=65.0
# step = 5358, loss = 0.045155152678489685, avg_reward=63.8
# step = 5359, loss = 0.05189063400030136, avg_reward=68.0
# step = 5360, loss = 0.05485750734806061, avg_reward=66.2
# step = 5361, loss = 0.04890352487564087, avg_reward=58.7
# step = 5362, loss = 0.024387234821915627, avg_reward=60.3
# step = 5363, loss = 0.022792372852563858, avg_reward=76.1
# step = 5364, loss = 0.07627353817224503, avg_reward=48.7
# step = 5365, loss = 0.04039032757282257, avg_reward=74.0
# step = 5366, loss = 0.022037731483578682, avg_reward=69.4
# step = 5367, loss = 0.02340967208147049, avg_reward=63.1
# step = 5368, loss = 0.011566895991563797, avg_reward=63.6
# step = 5369, loss = 0.05337528511881828, avg_reward=65.0
# step = 5370, loss = 0.06466466188430786, avg_reward=55.1
# step = 5371, loss = 0.03284367173910141, avg_reward=70.1
# step = 5372, loss = 0.06276847422122955, avg_reward=64.1
# step = 5373, loss = 0.020192136988043785, avg_reward=63.3
# step = 5374, loss = 0.0361037440598011, avg_reward=64.3
# step = 5375, loss = 0.09860315173864365, avg_reward=55.2
# step = 5376, loss = 0.07399286329746246, avg_reward=59.4
# step = 5377, loss = 0.03244193643331528, avg_reward=76.9
# step = 5378, loss = 0.034290265291929245, avg_reward=56.3
# step = 5379, loss = 0.03408576548099518, avg_reward=74.2
# step = 5380, loss = 0.03506290912628174, avg_reward=71.6
# step = 5381, loss = 0.047236375510692596, avg_reward=51.9
# step = 5382, loss = 0.02728557027876377, avg_reward=63.2
# step = 5383, loss = 0.03092496283352375, avg_reward=65.9
# step = 5384, loss = 0.07016685605049133, avg_reward=61.5
# step = 5385, loss = 0.03597842901945114, avg_reward=65.4
# step = 5386, loss = 0.012101300060749054, avg_reward=69.8
# step = 5387, loss = 0.04715016856789589, avg_reward=66.1
# step = 5388, loss = 0.0407484732568264, avg_reward=71.6
# step = 5389, loss = 0.02526974305510521, avg_reward=60.6
# step = 5390, loss = 0.029225999489426613, avg_reward=72.3
# step = 5391, loss = 0.02951939031481743, avg_reward=71.1
# step = 5392, loss = 0.030445478856563568, avg_reward=75.1
# step = 5393, loss = 0.09408628940582275, avg_reward=66.4
# step = 5394, loss = 0.05309984087944031, avg_reward=73.2
# step = 5395, loss = 0.05056513100862503, avg_reward=72.8
# step = 5396, loss = 0.03142423555254936, avg_reward=57.5
# step = 5397, loss = 0.04936709254980087, avg_reward=61.2
# step = 5398, loss = 0.07020699232816696, avg_reward=67.9
# step = 5399, loss = 0.05055524781346321, avg_reward=74.6
# step = 5400, loss = 0.04590228945016861, avg_reward=65.3
# step = 5401, loss = 0.062150973826646805, avg_reward=79.9
# step = 5402, loss = 0.06105063110589981, avg_reward=67.6
# step = 5403, loss = 0.05908697471022606, avg_reward=60.6
# step = 5404, loss = 0.05822543799877167, avg_reward=58.4
# step = 5405, loss = 0.04486390948295593, avg_reward=75.1
# step = 5406, loss = 0.04479260742664337, avg_reward=68.7
# step = 5407, loss = 0.11809643357992172, avg_reward=77.1
# step = 5408, loss = 0.0510808601975441, avg_reward=67.2
# step = 5409, loss = 0.07718680053949356, avg_reward=69.0
# step = 5410, loss = 0.06947298347949982, avg_reward=55.4
# step = 5411, loss = 0.037951063364744186, avg_reward=64.0
# step = 5412, loss = 0.01674129068851471, avg_reward=66.2
# step = 5413, loss = 0.015853429213166237, avg_reward=72.0
# step = 5414, loss = 0.04823160544037819, avg_reward=61.4
# step = 5415, loss = 0.031139995902776718, avg_reward=74.9
# step = 5416, loss = 0.07461461424827576, avg_reward=62.7
# step = 5417, loss = 0.03652464598417282, avg_reward=57.8
# step = 5418, loss = 0.040464889258146286, avg_reward=69.4
# step = 5419, loss = 0.06767025589942932, avg_reward=73.6
# step = 5420, loss = 0.04900903254747391, avg_reward=66.8
# step = 5421, loss = 0.03196569159626961, avg_reward=84.1
# step = 5422, loss = 0.03389021381735802, avg_reward=79.0
# step = 5423, loss = 0.02934306487441063, avg_reward=74.0
# step = 5424, loss = 0.042517900466918945, avg_reward=56.8
# step = 5425, loss = 0.030106592923402786, avg_reward=68.4
# step = 5426, loss = 0.0622786246240139, avg_reward=67.1
# step = 5427, loss = 0.05398283526301384, avg_reward=70.8
# step = 5428, loss = 0.0184723362326622, avg_reward=67.4
# step = 5429, loss = 0.03776468336582184, avg_reward=70.3
# step = 5430, loss = 0.03466640040278435, avg_reward=70.4
# step = 5431, loss = 0.044427938759326935, avg_reward=56.6
# step = 5432, loss = 0.028355557471513748, avg_reward=58.7
# step = 5433, loss = 0.032173290848731995, avg_reward=64.6
# step = 5434, loss = 0.042308323085308075, avg_reward=64.4
# step = 5435, loss = 0.12321709096431732, avg_reward=67.8
# step = 5436, loss = 0.05956029146909714, avg_reward=51.7
# step = 5437, loss = 0.06749080866575241, avg_reward=68.0
# step = 5438, loss = 0.03550434857606888, avg_reward=71.0
# step = 5439, loss = 0.05411837249994278, avg_reward=51.9
# step = 5440, loss = 0.04115080088376999, avg_reward=68.6
# step = 5441, loss = 0.07532935589551926, avg_reward=63.3
# step = 5442, loss = 0.03828506916761398, avg_reward=57.8
# step = 5443, loss = 0.05076409876346588, avg_reward=57.5
# step = 5444, loss = 0.033998604863882065, avg_reward=77.1
# step = 5445, loss = 0.05179808288812637, avg_reward=56.5
# step = 5446, loss = 0.04445292055606842, avg_reward=56.3
# step = 5447, loss = 0.04999268054962158, avg_reward=67.2
# step = 5448, loss = 0.08110920339822769, avg_reward=63.6
# step = 5449, loss = 0.05100056901574135, avg_reward=63.5
# step = 5450, loss = 0.026698166504502296, avg_reward=58.4
# step = 5451, loss = 0.047849901020526886, avg_reward=64.2
# step = 5452, loss = 0.05720721557736397, avg_reward=78.9
# step = 5453, loss = 0.03578266128897667, avg_reward=54.3
# step = 5454, loss = 0.036057569086551666, avg_reward=68.4
# step = 5455, loss = 0.05433575063943863, avg_reward=70.3
# step = 5456, loss = 0.04059703275561333, avg_reward=64.8
# step = 5457, loss = 0.05005946755409241, avg_reward=50.6
# step = 5458, loss = 0.03398218750953674, avg_reward=78.9
# step = 5459, loss = 0.008706538006663322, avg_reward=60.7
# step = 5460, loss = 0.05565359443426132, avg_reward=55.8
# step = 5461, loss = 0.025604285299777985, avg_reward=56.9
# step = 5462, loss = 0.01951552927494049, avg_reward=68.6
# step = 5463, loss = 0.04224438965320587, avg_reward=65.1
# step = 5464, loss = 0.03142596781253815, avg_reward=56.2
# step = 5465, loss = 0.04620214179158211, avg_reward=57.8
# step = 5466, loss = 0.0649639219045639, avg_reward=66.1
# step = 5467, loss = 0.06265653669834137, avg_reward=63.3
# step = 5468, loss = 0.051426541060209274, avg_reward=56.8
# step = 5469, loss = 0.0579402856528759, avg_reward=69.6
# step = 5470, loss = 0.03390306979417801, avg_reward=65.0
# step = 5471, loss = 0.05912104994058609, avg_reward=62.6
# step = 5472, loss = 0.03767118602991104, avg_reward=66.9
# step = 5473, loss = 0.0463312491774559, avg_reward=63.5
# step = 5474, loss = 0.05339609086513519, avg_reward=73.8
# step = 5475, loss = 0.008079778403043747, avg_reward=67.6
# step = 5476, loss = 0.031984396278858185, avg_reward=72.6
# step = 5477, loss = 0.017326444387435913, avg_reward=72.0
# step = 5478, loss = 0.04489296302199364, avg_reward=66.3
# step = 5479, loss = 0.09669186174869537, avg_reward=58.1
# step = 5480, loss = 0.03664553537964821, avg_reward=58.3
# step = 5481, loss = 0.02916671894490719, avg_reward=85.9
# step = 5482, loss = 0.06376369297504425, avg_reward=66.8
# step = 5483, loss = 0.03552214056253433, avg_reward=71.3
# step = 5484, loss = 0.04848627746105194, avg_reward=60.8
# step = 5485, loss = 0.02678663283586502, avg_reward=71.0
# step = 5486, loss = 0.055348485708236694, avg_reward=60.5
# step = 5487, loss = 0.05510127916932106, avg_reward=75.8
# step = 5488, loss = 0.07366073131561279, avg_reward=57.0
# step = 5489, loss = 0.056018806993961334, avg_reward=59.4
# step = 5490, loss = 0.03142156824469566, avg_reward=65.4
# step = 5491, loss = 0.03642857074737549, avg_reward=62.2
# step = 5492, loss = 0.04643574357032776, avg_reward=63.7
# step = 5493, loss = 0.047859106212854385, avg_reward=72.0
# step = 5494, loss = 0.05056293308734894, avg_reward=65.4
# step = 5495, loss = 0.026455562561750412, avg_reward=57.5
# step = 5496, loss = 0.02459918148815632, avg_reward=55.7
# step = 5497, loss = 0.018728315830230713, avg_reward=57.9
# step = 5498, loss = 0.04153900593519211, avg_reward=70.5
# step = 5499, loss = 0.04082918167114258, avg_reward=62.4
# step = 5500, loss = 0.0594375878572464, avg_reward=58.1
# step = 5501, loss = 0.039101481437683105, avg_reward=61.4
# step = 5502, loss = 0.04018840938806534, avg_reward=53.0
# step = 5503, loss = 0.06988169252872467, avg_reward=58.6
# step = 5504, loss = 0.04106272757053375, avg_reward=84.0
# step = 5505, loss = 0.02449755370616913, avg_reward=66.9
# step = 5506, loss = 0.023981187492609024, avg_reward=62.2
# step = 5507, loss = 0.04740200936794281, avg_reward=61.5
# step = 5508, loss = 0.017419660463929176, avg_reward=47.7
# step = 5509, loss = 0.05214115232229233, avg_reward=70.1
# step = 5510, loss = 0.015435807406902313, avg_reward=69.7
# step = 5511, loss = 0.025075573474168777, avg_reward=69.4
# step = 5512, loss = 0.023775771260261536, avg_reward=59.7
# step = 5513, loss = 0.03857475519180298, avg_reward=60.8
# step = 5514, loss = 0.04627620428800583, avg_reward=61.9
# step = 5515, loss = 0.0184001624584198, avg_reward=65.8
# step = 5516, loss = 0.034870438277721405, avg_reward=76.4
# step = 5517, loss = 0.06852655112743378, avg_reward=63.5
# step = 5518, loss = 0.04593394696712494, avg_reward=66.5
# step = 5519, loss = 0.018799904733896255, avg_reward=61.9
# step = 5520, loss = 0.04301883652806282, avg_reward=68.4
# step = 5521, loss = 0.04907181113958359, avg_reward=68.8
# step = 5522, loss = 0.032928284257650375, avg_reward=56.5
# step = 5523, loss = 0.06902847439050674, avg_reward=63.7
# step = 5524, loss = 0.03385978564620018, avg_reward=59.9
# step = 5525, loss = 0.0417710579931736, avg_reward=54.8
# step = 5526, loss = 0.04108901694417, avg_reward=58.7
# step = 5527, loss = 0.0700988918542862, avg_reward=62.4
# step = 5528, loss = 0.024044528603553772, avg_reward=65.2
# step = 5529, loss = 0.037559784948825836, avg_reward=70.8
# step = 5530, loss = 0.04007465019822121, avg_reward=58.5
# step = 5531, loss = 0.027157064527273178, avg_reward=76.1
# step = 5532, loss = 0.045433178544044495, avg_reward=57.4
# step = 5533, loss = 0.02658313885331154, avg_reward=59.9
# step = 5534, loss = 0.014805709943175316, avg_reward=65.3
# step = 5535, loss = 0.04943932965397835, avg_reward=59.0
# step = 5536, loss = 0.06457585096359253, avg_reward=71.1
# step = 5537, loss = 0.022416910156607628, avg_reward=65.7
# step = 5538, loss = 0.025239689275622368, avg_reward=71.9
# step = 5539, loss = 0.03694169223308563, avg_reward=69.6
# step = 5540, loss = 0.06620344519615173, avg_reward=88.1
# step = 5541, loss = 0.05662362650036812, avg_reward=57.5
# step = 5542, loss = 0.03897808492183685, avg_reward=55.0
# step = 5543, loss = 0.04866127669811249, avg_reward=65.8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-4fce5538d59b> in <module>
#       9   #print(gameplay_experience_batch)
#      10   loss = ai_agent.train(states, rewards, actions, next_states, dones)
# ---> 11   avg_reward = evaluate_training_result(env, ai_agent)
#      12   print("step = {}, loss = {}, avg_reward={}".format(s, loss, avg_reward))
#      13   # done = False
#
# <ipython-input-73-7c9b12779934> in evaluate_training_result(env, agent)
#      15         episode_reward = 0.0
#      16         while not done:
# ---> 17             action = agent.policy(state)
#      18             next_state, reward, done, _ = env.step(action)
#      19             episode_reward += reward
#
# <ipython-input-70-88b19ee5512c> in policy(self, state)
#      25
#      26   def policy(self, state):
# ---> 27     prob = self.q_net(tf.reshape(state, [-1, 4]))
#      28     action = tf.math.argmax(prob, axis=1)
#      29     #print("prob:", prob, "action:", action)
#
# ~/Library/Python/3.8/lib/python/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/Library/Python/3.8/lib/python/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1081         with autocast_variable.enable_auto_cast_variables(
#    1082             self._compute_dtype_object):
# -> 1083           outputs = call_fn(inputs, *args, **kwargs)
#    1084
#    1085         if self._activity_regularizer:
#
# ~/Library/Python/3.8/lib/python/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# <ipython-input-5-1cf42e026f26> in call(self, input_data)
#       9   def call(self, input_data):
#      10     x = tf.convert_to_tensor(input_data)
# ---> 11     x = self.d1(x)
#      12     x = self.d2(x)
#      13     x = self.out(x)
#
# ~/Library/Python/3.8/lib/python/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/Library/Python/3.8/lib/python/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1026     if any(isinstance(x, (
#    1027         tf.Tensor, np.ndarray, float, int)) for x in input_list):
# -> 1028       inputs = tf.nest.map_structure(_convert_numpy_or_python_types, inputs)
#    1029       input_list = tf.nest.flatten(inputs)
#    1030
#
# ~/Library/Python/3.8/lib/python/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     866   entries = zip(*flat_structure)
#     867
# --> 868   return pack_sequence_as(
#     869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#
# ~/Library/Python/3.8/lib/python/site-packages/tensorflow/python/util/nest.py in pack_sequence_as(structure, flat_sequence, expand_composites)
#     755     TypeError: `structure` is or contains a dict with non-sortable keys.
#     756   """
# --> 757   return _pack_sequence_as(structure, flat_sequence, expand_composites)
#     758
#     759
#
# ~/Library/Python/3.8/lib/python/site-packages/tensorflow/python/util/nest.py in _pack_sequence_as(structure, flat_sequence, expand_composites, sequence_fn)
#     620
#     621   if not is_seq(structure):
# --> 622     if len(flat_sequence) != 1:
#     623       raise ValueError(
#     624           "The target structure is of type `{}`\n  {}\nHowever the input "
#
# KeyboardInterrupt:

# %%
state
# Out:
# array([-0.01219752,  0.04356086, -0.01093986, -0.03999828], dtype=float32)

# %%
ai_agent.collect_policy(state)
# Out:
# prob: tf.Tensor([[-0.00357938 -0.00206238]], shape=(1, 2), dtype=float32)
# action: tf.Tensor([2.], shape=(1,), dtype=float32)
# 2

# %%
def ai_play(ai_agent):
    env = gym.make('CartPole-v1')
    state = env.reset()

    done = False
    step = 0
    total_reward = 0
    while not done:
        env.render()
        action = ai_agent.predict(state)
        next_state, reward, done, _ = env.step(action)
        state = next_state
        step += 1
        total_reward += reward

        print("step: {} action: {}, total_reward: {}, done:{}".format(step, action, total_reward, done))
        if done:
            break
    env.reset()
    env.close()

# %%
ai_play(ai_agent)
# Out:
# step: 1 action: 1, total_reward: 1.0, done:False
# step: 2 action: 0, total_reward: 2.0, done:False
# step: 3 action: 1, total_reward: 3.0, done:False
# step: 4 action: 0, total_reward: 4.0, done:False
# step: 5 action: 0, total_reward: 5.0, done:False
# step: 6 action: 1, total_reward: 6.0, done:False
# step: 7 action: 0, total_reward: 7.0, done:False
# step: 8 action: 1, total_reward: 8.0, done:False
# step: 9 action: 0, total_reward: 9.0, done:False
# step: 10 action: 1, total_reward: 10.0, done:False
# step: 11 action: 0, total_reward: 11.0, done:False
# step: 12 action: 1, total_reward: 12.0, done:False
# step: 13 action: 0, total_reward: 13.0, done:False
# step: 14 action: 1, total_reward: 14.0, done:False
# step: 15 action: 0, total_reward: 15.0, done:False
# step: 16 action: 1, total_reward: 16.0, done:False
# step: 17 action: 0, total_reward: 17.0, done:False
# step: 18 action: 1, total_reward: 18.0, done:False
# step: 19 action: 0, total_reward: 19.0, done:False
# step: 20 action: 1, total_reward: 20.0, done:False
# step: 21 action: 1, total_reward: 21.0, done:False
# step: 22 action: 0, total_reward: 22.0, done:False
# step: 23 action: 1, total_reward: 23.0, done:False
# step: 24 action: 0, total_reward: 24.0, done:False
# step: 25 action: 1, total_reward: 25.0, done:False
# step: 26 action: 0, total_reward: 26.0, done:False
# step: 27 action: 1, total_reward: 27.0, done:False
# step: 28 action: 0, total_reward: 28.0, done:False
# step: 29 action: 1, total_reward: 29.0, done:False
# step: 30 action: 0, total_reward: 30.0, done:False
# step: 31 action: 1, total_reward: 31.0, done:False
# step: 32 action: 0, total_reward: 32.0, done:False
# step: 33 action: 1, total_reward: 33.0, done:False
# step: 34 action: 0, total_reward: 34.0, done:False
# step: 35 action: 0, total_reward: 35.0, done:False
# step: 36 action: 1, total_reward: 36.0, done:False
# step: 37 action: 0, total_reward: 37.0, done:False
# step: 38 action: 1, total_reward: 38.0, done:False
# step: 39 action: 0, total_reward: 39.0, done:False
# step: 40 action: 1, total_reward: 40.0, done:False
# step: 41 action: 0, total_reward: 41.0, done:False
# step: 42 action: 1, total_reward: 42.0, done:False
# step: 43 action: 0, total_reward: 43.0, done:False
# step: 44 action: 1, total_reward: 44.0, done:False
# step: 45 action: 1, total_reward: 45.0, done:False
# step: 46 action: 0, total_reward: 46.0, done:False
# step: 47 action: 1, total_reward: 47.0, done:False
# step: 48 action: 0, total_reward: 48.0, done:False
# step: 49 action: 1, total_reward: 49.0, done:False
# step: 50 action: 0, total_reward: 50.0, done:False
# step: 51 action: 1, total_reward: 51.0, done:False
# step: 52 action: 0, total_reward: 52.0, done:False
# step: 53 action: 0, total_reward: 53.0, done:False
# step: 54 action: 1, total_reward: 54.0, done:False
# step: 55 action: 0, total_reward: 55.0, done:False
# step: 56 action: 1, total_reward: 56.0, done:False
# step: 57 action: 0, total_reward: 57.0, done:False
# step: 58 action: 1, total_reward: 58.0, done:False
# step: 59 action: 1, total_reward: 59.0, done:False
# step: 60 action: 0, total_reward: 60.0, done:False
# step: 61 action: 1, total_reward: 61.0, done:False
# step: 62 action: 0, total_reward: 62.0, done:False
# step: 63 action: 0, total_reward: 63.0, done:False
# step: 64 action: 1, total_reward: 64.0, done:False
# step: 65 action: 0, total_reward: 65.0, done:False
# step: 66 action: 1, total_reward: 66.0, done:False
# step: 67 action: 1, total_reward: 67.0, done:False
# step: 68 action: 0, total_reward: 68.0, done:False
# step: 69 action: 1, total_reward: 69.0, done:False
# step: 70 action: 0, total_reward: 70.0, done:False
# step: 71 action: 0, total_reward: 71.0, done:False
# step: 72 action: 1, total_reward: 72.0, done:False
# step: 73 action: 0, total_reward: 73.0, done:False
# step: 74 action: 1, total_reward: 74.0, done:False
# step: 75 action: 1, total_reward: 75.0, done:False
# step: 76 action: 0, total_reward: 76.0, done:False
# step: 77 action: 1, total_reward: 77.0, done:False
# step: 78 action: 0, total_reward: 78.0, done:False
# step: 79 action: 0, total_reward: 79.0, done:False
# step: 80 action: 1, total_reward: 80.0, done:False
# step: 81 action: 1, total_reward: 81.0, done:False
# step: 82 action: 0, total_reward: 82.0, done:False
# step: 83 action: 0, total_reward: 83.0, done:False
# step: 84 action: 1, total_reward: 84.0, done:False
# step: 85 action: 0, total_reward: 85.0, done:False
# step: 86 action: 1, total_reward: 86.0, done:False
# step: 87 action: 1, total_reward: 87.0, done:False
# step: 88 action: 0, total_reward: 88.0, done:False
# step: 89 action: 1, total_reward: 89.0, done:False
# step: 90 action: 0, total_reward: 90.0, done:False
# step: 91 action: 0, total_reward: 91.0, done:False
# step: 92 action: 1, total_reward: 92.0, done:False
# step: 93 action: 0, total_reward: 93.0, done:False
# step: 94 action: 1, total_reward: 94.0, done:False
# step: 95 action: 1, total_reward: 95.0, done:False
# step: 96 action: 0, total_reward: 96.0, done:False
# step: 97 action: 1, total_reward: 97.0, done:False
# step: 98 action: 0, total_reward: 98.0, done:False
# step: 99 action: 0, total_reward: 99.0, done:False
# step: 100 action: 1, total_reward: 100.0, done:False
# step: 101 action: 1, total_reward: 101.0, done:False
# step: 102 action: 0, total_reward: 102.0, done:False
# step: 103 action: 0, total_reward: 103.0, done:False
# step: 104 action: 1, total_reward: 104.0, done:False
# step: 105 action: 0, total_reward: 105.0, done:False
# step: 106 action: 1, total_reward: 106.0, done:False
# step: 107 action: 1, total_reward: 107.0, done:False
# step: 108 action: 0, total_reward: 108.0, done:False
# step: 109 action: 1, total_reward: 109.0, done:False
# step: 110 action: 0, total_reward: 110.0, done:False
# step: 111 action: 0, total_reward: 111.0, done:False
# step: 112 action: 1, total_reward: 112.0, done:False
# step: 113 action: 0, total_reward: 113.0, done:False
# step: 114 action: 1, total_reward: 114.0, done:False
# step: 115 action: 1, total_reward: 115.0, done:False
# step: 116 action: 0, total_reward: 116.0, done:False
# step: 117 action: 1, total_reward: 117.0, done:False
# step: 118 action: 0, total_reward: 118.0, done:False
# step: 119 action: 0, total_reward: 119.0, done:False
# step: 120 action: 1, total_reward: 120.0, done:False
# step: 121 action: 1, total_reward: 121.0, done:False
# step: 122 action: 0, total_reward: 122.0, done:False
# step: 123 action: 0, total_reward: 123.0, done:False
# step: 124 action: 1, total_reward: 124.0, done:False
# step: 125 action: 0, total_reward: 125.0, done:False
# step: 126 action: 1, total_reward: 126.0, done:False
# step: 127 action: 1, total_reward: 127.0, done:False
# step: 128 action: 0, total_reward: 128.0, done:False
# step: 129 action: 1, total_reward: 129.0, done:False
# step: 130 action: 0, total_reward: 130.0, done:False
# step: 131 action: 0, total_reward: 131.0, done:False
# step: 132 action: 1, total_reward: 132.0, done:False
# step: 133 action: 1, total_reward: 133.0, done:False
# step: 134 action: 0, total_reward: 134.0, done:False
# step: 135 action: 0, total_reward: 135.0, done:False
# step: 136 action: 1, total_reward: 136.0, done:False
# step: 137 action: 0, total_reward: 137.0, done:False
# step: 138 action: 1, total_reward: 138.0, done:False
# step: 139 action: 1, total_reward: 139.0, done:False
# step: 140 action: 0, total_reward: 140.0, done:False
# step: 141 action: 1, total_reward: 141.0, done:False
# step: 142 action: 0, total_reward: 142.0, done:False
# step: 143 action: 0, total_reward: 143.0, done:False
# step: 144 action: 1, total_reward: 144.0, done:False
# step: 145 action: 0, total_reward: 145.0, done:False
# step: 146 action: 1, total_reward: 146.0, done:False
# step: 147 action: 1, total_reward: 147.0, done:False
# step: 148 action: 0, total_reward: 148.0, done:False
# step: 149 action: 1, total_reward: 149.0, done:False
# step: 150 action: 0, total_reward: 150.0, done:False
# step: 151 action: 0, total_reward: 151.0, done:False
# step: 152 action: 1, total_reward: 152.0, done:False
# step: 153 action: 0, total_reward: 153.0, done:False
# step: 154 action: 1, total_reward: 154.0, done:False
# step: 155 action: 1, total_reward: 155.0, done:False
# step: 156 action: 0, total_reward: 156.0, done:False
# step: 157 action: 1, total_reward: 157.0, done:False
# step: 158 action: 0, total_reward: 158.0, done:False
# step: 159 action: 0, total_reward: 159.0, done:False
# step: 160 action: 1, total_reward: 160.0, done:False
# step: 161 action: 1, total_reward: 161.0, done:False
# step: 162 action: 0, total_reward: 162.0, done:False
# step: 163 action: 0, total_reward: 163.0, done:False
# step: 164 action: 1, total_reward: 164.0, done:False
# step: 165 action: 0, total_reward: 165.0, done:False
# step: 166 action: 1, total_reward: 166.0, done:False
# step: 167 action: 1, total_reward: 167.0, done:False
# step: 168 action: 0, total_reward: 168.0, done:False
# step: 169 action: 1, total_reward: 169.0, done:False
# step: 170 action: 0, total_reward: 170.0, done:False
# step: 171 action: 0, total_reward: 171.0, done:False
# step: 172 action: 1, total_reward: 172.0, done:False
# step: 173 action: 0, total_reward: 173.0, done:False
# step: 174 action: 1, total_reward: 174.0, done:False
# step: 175 action: 1, total_reward: 175.0, done:False
# step: 176 action: 0, total_reward: 176.0, done:False
# step: 177 action: 0, total_reward: 177.0, done:False
# step: 178 action: 1, total_reward: 178.0, done:False
# step: 179 action: 1, total_reward: 179.0, done:False
# step: 180 action: 0, total_reward: 180.0, done:False
# step: 181 action: 1, total_reward: 181.0, done:False
# step: 182 action: 0, total_reward: 182.0, done:False
# step: 183 action: 0, total_reward: 183.0, done:False
# step: 184 action: 1, total_reward: 184.0, done:False
# step: 185 action: 0, total_reward: 185.0, done:False
# step: 186 action: 1, total_reward: 186.0, done:False
# step: 187 action: 1, total_reward: 187.0, done:False
# step: 188 action: 0, total_reward: 188.0, done:False
# step: 189 action: 1, total_reward: 189.0, done:False
# step: 190 action: 0, total_reward: 190.0, done:False
# step: 191 action: 0, total_reward: 191.0, done:False
# step: 192 action: 1, total_reward: 192.0, done:False
# step: 193 action: 0, total_reward: 193.0, done:False
# step: 194 action: 1, total_reward: 194.0, done:False
# step: 195 action: 1, total_reward: 195.0, done:False
# step: 196 action: 0, total_reward: 196.0, done:False
# step: 197 action: 0, total_reward: 197.0, done:False
# step: 198 action: 1, total_reward: 198.0, done:False
# step: 199 action: 1, total_reward: 199.0, done:False
# step: 200 action: 0, total_reward: 200.0, done:False
# step: 201 action: 1, total_reward: 201.0, done:False
# step: 202 action: 0, total_reward: 202.0, done:False
# step: 203 action: 0, total_reward: 203.0, done:False
# step: 204 action: 1, total_reward: 204.0, done:False
# step: 205 action: 0, total_reward: 205.0, done:False
# step: 206 action: 1, total_reward: 206.0, done:False
# step: 207 action: 1, total_reward: 207.0, done:False
# step: 208 action: 0, total_reward: 208.0, done:False
# step: 209 action: 0, total_reward: 209.0, done:False
# step: 210 action: 1, total_reward: 210.0, done:False
# step: 211 action: 1, total_reward: 211.0, done:False
# step: 212 action: 0, total_reward: 212.0, done:False
# step: 213 action: 1, total_reward: 213.0, done:False
# step: 214 action: 0, total_reward: 214.0, done:False
# step: 215 action: 0, total_reward: 215.0, done:False
# step: 216 action: 1, total_reward: 216.0, done:False
# step: 217 action: 0, total_reward: 217.0, done:False
# step: 218 action: 1, total_reward: 218.0, done:False
# step: 219 action: 0, total_reward: 219.0, done:False
# step: 220 action: 1, total_reward: 220.0, done:False
# step: 221 action: 1, total_reward: 221.0, done:False
# step: 222 action: 0, total_reward: 222.0, done:False
# step: 223 action: 1, total_reward: 223.0, done:False
# step: 224 action: 0, total_reward: 224.0, done:False
# step: 225 action: 1, total_reward: 225.0, done:False
# step: 226 action: 0, total_reward: 226.0, done:False
# step: 227 action: 1, total_reward: 227.0, done:False
# step: 228 action: 0, total_reward: 228.0, done:False
# step: 229 action: 0, total_reward: 229.0, done:False
# step: 230 action: 1, total_reward: 230.0, done:False
# step: 231 action: 0, total_reward: 231.0, done:False
# step: 232 action: 1, total_reward: 232.0, done:False
# step: 233 action: 0, total_reward: 233.0, done:False
# step: 234 action: 1, total_reward: 234.0, done:False
# step: 235 action: 0, total_reward: 235.0, done:False
# step: 236 action: 1, total_reward: 236.0, done:False
# step: 237 action: 1, total_reward: 237.0, done:False
# step: 238 action: 0, total_reward: 238.0, done:False
# step: 239 action: 1, total_reward: 239.0, done:False
# step: 240 action: 0, total_reward: 240.0, done:False
# step: 241 action: 0, total_reward: 241.0, done:False
# step: 242 action: 1, total_reward: 242.0, done:False
# step: 243 action: 1, total_reward: 243.0, done:False
# step: 244 action: 0, total_reward: 244.0, done:False
# step: 245 action: 0, total_reward: 245.0, done:False
# step: 246 action: 1, total_reward: 246.0, done:False
# step: 247 action: 1, total_reward: 247.0, done:False
# step: 248 action: 0, total_reward: 248.0, done:False
# step: 249 action: 0, total_reward: 249.0, done:False
# step: 250 action: 1, total_reward: 250.0, done:False
# step: 251 action: 1, total_reward: 251.0, done:False
# step: 252 action: 0, total_reward: 252.0, done:False
# step: 253 action: 0, total_reward: 253.0, done:False
# step: 254 action: 1, total_reward: 254.0, done:False
# step: 255 action: 1, total_reward: 255.0, done:False
# step: 256 action: 0, total_reward: 256.0, done:False
# step: 257 action: 0, total_reward: 257.0, done:False
# step: 258 action: 1, total_reward: 258.0, done:False
# step: 259 action: 1, total_reward: 259.0, done:False
# step: 260 action: 0, total_reward: 260.0, done:False
# step: 261 action: 0, total_reward: 261.0, done:False
# step: 262 action: 1, total_reward: 262.0, done:False
# step: 263 action: 0, total_reward: 263.0, done:False
# step: 264 action: 1, total_reward: 264.0, done:False
# step: 265 action: 1, total_reward: 265.0, done:False
# step: 266 action: 0, total_reward: 266.0, done:False
# step: 267 action: 1, total_reward: 267.0, done:False
# step: 268 action: 0, total_reward: 268.0, done:False
# step: 269 action: 1, total_reward: 269.0, done:False
# step: 270 action: 0, total_reward: 270.0, done:False
# step: 271 action: 0, total_reward: 271.0, done:False
# step: 272 action: 1, total_reward: 272.0, done:False
# step: 273 action: 0, total_reward: 273.0, done:False
# step: 274 action: 1, total_reward: 274.0, done:False
# step: 275 action: 0, total_reward: 275.0, done:False
# step: 276 action: 1, total_reward: 276.0, done:False
# step: 277 action: 1, total_reward: 277.0, done:False
# step: 278 action: 0, total_reward: 278.0, done:False
# step: 279 action: 1, total_reward: 279.0, done:False
# step: 280 action: 0, total_reward: 280.0, done:False
# step: 281 action: 0, total_reward: 281.0, done:False
# step: 282 action: 1, total_reward: 282.0, done:False
# step: 283 action: 1, total_reward: 283.0, done:False
# step: 284 action: 0, total_reward: 284.0, done:False
# step: 285 action: 0, total_reward: 285.0, done:False
# step: 286 action: 1, total_reward: 286.0, done:False
# step: 287 action: 1, total_reward: 287.0, done:False
# step: 288 action: 0, total_reward: 288.0, done:False
# step: 289 action: 0, total_reward: 289.0, done:False
# step: 290 action: 1, total_reward: 290.0, done:False
# step: 291 action: 1, total_reward: 291.0, done:False
# step: 292 action: 0, total_reward: 292.0, done:False
# step: 293 action: 0, total_reward: 293.0, done:False
# step: 294 action: 1, total_reward: 294.0, done:False
# step: 295 action: 0, total_reward: 295.0, done:False
# step: 296 action: 1, total_reward: 296.0, done:False
# step: 297 action: 1, total_reward: 297.0, done:False
# step: 298 action: 0, total_reward: 298.0, done:False
# step: 299 action: 1, total_reward: 299.0, done:False
# step: 300 action: 0, total_reward: 300.0, done:False
# step: 301 action: 1, total_reward: 301.0, done:False
# step: 302 action: 0, total_reward: 302.0, done:False
# step: 303 action: 0, total_reward: 303.0, done:False
# step: 304 action: 1, total_reward: 304.0, done:False
# step: 305 action: 0, total_reward: 305.0, done:False
# step: 306 action: 1, total_reward: 306.0, done:False
# step: 307 action: 0, total_reward: 307.0, done:False
# step: 308 action: 1, total_reward: 308.0, done:False
# step: 309 action: 1, total_reward: 309.0, done:False
# step: 310 action: 0, total_reward: 310.0, done:False
# step: 311 action: 1, total_reward: 311.0, done:False
# step: 312 action: 0, total_reward: 312.0, done:False
# step: 313 action: 0, total_reward: 313.0, done:False
# step: 314 action: 1, total_reward: 314.0, done:False
# step: 315 action: 0, total_reward: 315.0, done:False
# step: 316 action: 1, total_reward: 316.0, done:False
# step: 317 action: 1, total_reward: 317.0, done:False
# step: 318 action: 0, total_reward: 318.0, done:False
# step: 319 action: 1, total_reward: 319.0, done:False
# step: 320 action: 0, total_reward: 320.0, done:False
# step: 321 action: 1, total_reward: 321.0, done:False
# step: 322 action: 0, total_reward: 322.0, done:False
# step: 323 action: 0, total_reward: 323.0, done:False
# step: 324 action: 1, total_reward: 324.0, done:False
# step: 325 action: 0, total_reward: 325.0, done:False
# step: 326 action: 1, total_reward: 326.0, done:False
# step: 327 action: 0, total_reward: 327.0, done:False
# step: 328 action: 1, total_reward: 328.0, done:False
# step: 329 action: 0, total_reward: 329.0, done:False
# step: 330 action: 1, total_reward: 330.0, done:False
# step: 331 action: 1, total_reward: 331.0, done:False
# step: 332 action: 0, total_reward: 332.0, done:False
# step: 333 action: 1, total_reward: 333.0, done:False
# step: 334 action: 0, total_reward: 334.0, done:False
# step: 335 action: 1, total_reward: 335.0, done:False
# step: 336 action: 0, total_reward: 336.0, done:False
# step: 337 action: 1, total_reward: 337.0, done:False
# step: 338 action: 0, total_reward: 338.0, done:False
# step: 339 action: 0, total_reward: 339.0, done:False
# step: 340 action: 1, total_reward: 340.0, done:False
# step: 341 action: 0, total_reward: 341.0, done:False
# step: 342 action: 1, total_reward: 342.0, done:False
# step: 343 action: 1, total_reward: 343.0, done:False
# step: 344 action: 0, total_reward: 344.0, done:False
# step: 345 action: 0, total_reward: 345.0, done:False
# step: 346 action: 1, total_reward: 346.0, done:False
# step: 347 action: 1, total_reward: 347.0, done:False
# step: 348 action: 0, total_reward: 348.0, done:False
# step: 349 action: 0, total_reward: 349.0, done:False
# step: 350 action: 1, total_reward: 350.0, done:False
# step: 351 action: 0, total_reward: 351.0, done:False
# step: 352 action: 1, total_reward: 352.0, done:False
# step: 353 action: 1, total_reward: 353.0, done:False
# step: 354 action: 0, total_reward: 354.0, done:False
# step: 355 action: 1, total_reward: 355.0, done:False
# step: 356 action: 0, total_reward: 356.0, done:False
# step: 357 action: 1, total_reward: 357.0, done:False
# step: 358 action: 0, total_reward: 358.0, done:False
# step: 359 action: 0, total_reward: 359.0, done:False
# step: 360 action: 1, total_reward: 360.0, done:False
# step: 361 action: 0, total_reward: 361.0, done:False
# step: 362 action: 1, total_reward: 362.0, done:False
# step: 363 action: 0, total_reward: 363.0, done:False
# step: 364 action: 1, total_reward: 364.0, done:False
# step: 365 action: 1, total_reward: 365.0, done:False
# step: 366 action: 0, total_reward: 366.0, done:False
# step: 367 action: 1, total_reward: 367.0, done:False
# step: 368 action: 0, total_reward: 368.0, done:False
# step: 369 action: 0, total_reward: 369.0, done:False
# step: 370 action: 1, total_reward: 370.0, done:False
# step: 371 action: 0, total_reward: 371.0, done:False
# step: 372 action: 1, total_reward: 372.0, done:False
# step: 373 action: 1, total_reward: 373.0, done:False
# step: 374 action: 0, total_reward: 374.0, done:False
# step: 375 action: 1, total_reward: 375.0, done:False
# step: 376 action: 0, total_reward: 376.0, done:False
# step: 377 action: 1, total_reward: 377.0, done:False
# step: 378 action: 0, total_reward: 378.0, done:False
# step: 379 action: 0, total_reward: 379.0, done:False
# step: 380 action: 1, total_reward: 380.0, done:False
# step: 381 action: 0, total_reward: 381.0, done:False
# step: 382 action: 1, total_reward: 382.0, done:False
# step: 383 action: 0, total_reward: 383.0, done:False
# step: 384 action: 1, total_reward: 384.0, done:False
# step: 385 action: 1, total_reward: 385.0, done:False
# step: 386 action: 0, total_reward: 386.0, done:False
# step: 387 action: 0, total_reward: 387.0, done:False
# step: 388 action: 1, total_reward: 388.0, done:False
# step: 389 action: 1, total_reward: 389.0, done:False
# step: 390 action: 0, total_reward: 390.0, done:False
# step: 391 action: 1, total_reward: 391.0, done:False
# step: 392 action: 0, total_reward: 392.0, done:False
# step: 393 action: 0, total_reward: 393.0, done:False
# step: 394 action: 1, total_reward: 394.0, done:False
# step: 395 action: 1, total_reward: 395.0, done:False
# step: 396 action: 0, total_reward: 396.0, done:False
# step: 397 action: 0, total_reward: 397.0, done:False
# step: 398 action: 1, total_reward: 398.0, done:False
# step: 399 action: 0, total_reward: 399.0, done:False
# step: 400 action: 1, total_reward: 400.0, done:False
# step: 401 action: 1, total_reward: 401.0, done:False
# step: 402 action: 0, total_reward: 402.0, done:False
# step: 403 action: 1, total_reward: 403.0, done:False
# step: 404 action: 0, total_reward: 404.0, done:False
# step: 405 action: 0, total_reward: 405.0, done:False
# step: 406 action: 1, total_reward: 406.0, done:False
# step: 407 action: 1, total_reward: 407.0, done:False
# step: 408 action: 0, total_reward: 408.0, done:False
# step: 409 action: 0, total_reward: 409.0, done:False
# step: 410 action: 1, total_reward: 410.0, done:False
# step: 411 action: 0, total_reward: 411.0, done:False
# step: 412 action: 1, total_reward: 412.0, done:False
# step: 413 action: 1, total_reward: 413.0, done:False
# step: 414 action: 0, total_reward: 414.0, done:False
# step: 415 action: 1, total_reward: 415.0, done:False
# step: 416 action: 0, total_reward: 416.0, done:False
# step: 417 action: 0, total_reward: 417.0, done:False
# step: 418 action: 1, total_reward: 418.0, done:False
# step: 419 action: 0, total_reward: 419.0, done:False
# step: 420 action: 1, total_reward: 420.0, done:False
# step: 421 action: 1, total_reward: 421.0, done:False
# step: 422 action: 0, total_reward: 422.0, done:False
# step: 423 action: 1, total_reward: 423.0, done:False
# step: 424 action: 0, total_reward: 424.0, done:False
# step: 425 action: 0, total_reward: 425.0, done:False
# step: 426 action: 1, total_reward: 426.0, done:False
# step: 427 action: 1, total_reward: 427.0, done:False
# step: 428 action: 0, total_reward: 428.0, done:False
# step: 429 action: 0, total_reward: 429.0, done:False
# step: 430 action: 1, total_reward: 430.0, done:False
# step: 431 action: 0, total_reward: 431.0, done:False
# step: 432 action: 1, total_reward: 432.0, done:False
# step: 433 action: 1, total_reward: 433.0, done:False
# step: 434 action: 0, total_reward: 434.0, done:False
# step: 435 action: 1, total_reward: 435.0, done:False
# step: 436 action: 0, total_reward: 436.0, done:False
# step: 437 action: 0, total_reward: 437.0, done:False
# step: 438 action: 1, total_reward: 438.0, done:False
# step: 439 action: 0, total_reward: 439.0, done:False
# step: 440 action: 1, total_reward: 440.0, done:False
# step: 441 action: 1, total_reward: 441.0, done:False
# step: 442 action: 0, total_reward: 442.0, done:False
# step: 443 action: 1, total_reward: 443.0, done:False
# step: 444 action: 0, total_reward: 444.0, done:False
# step: 445 action: 0, total_reward: 445.0, done:False
# step: 446 action: 1, total_reward: 446.0, done:False
# step: 447 action: 1, total_reward: 447.0, done:False
# step: 448 action: 0, total_reward: 448.0, done:False
# step: 449 action: 0, total_reward: 449.0, done:False
# step: 450 action: 1, total_reward: 450.0, done:False
# step: 451 action: 0, total_reward: 451.0, done:False
# step: 452 action: 1, total_reward: 452.0, done:False
# step: 453 action: 1, total_reward: 453.0, done:False
# step: 454 action: 0, total_reward: 454.0, done:False
# step: 455 action: 1, total_reward: 455.0, done:False
# step: 456 action: 0, total_reward: 456.0, done:False
# step: 457 action: 0, total_reward: 457.0, done:False
# step: 458 action: 1, total_reward: 458.0, done:False
# step: 459 action: 0, total_reward: 459.0, done:False
# step: 460 action: 1, total_reward: 460.0, done:False
# step: 461 action: 1, total_reward: 461.0, done:False
# step: 462 action: 0, total_reward: 462.0, done:False
# step: 463 action: 1, total_reward: 463.0, done:False
# step: 464 action: 0, total_reward: 464.0, done:False
# step: 465 action: 0, total_reward: 465.0, done:False
# step: 466 action: 1, total_reward: 466.0, done:False
# step: 467 action: 0, total_reward: 467.0, done:False
# step: 468 action: 1, total_reward: 468.0, done:False
# step: 469 action: 1, total_reward: 469.0, done:False
# step: 470 action: 0, total_reward: 470.0, done:False
# step: 471 action: 0, total_reward: 471.0, done:False
# step: 472 action: 1, total_reward: 472.0, done:False
# step: 473 action: 1, total_reward: 473.0, done:False
# step: 474 action: 0, total_reward: 474.0, done:False
# step: 475 action: 1, total_reward: 475.0, done:False
# step: 476 action: 0, total_reward: 476.0, done:False
# step: 477 action: 0, total_reward: 477.0, done:False
# step: 478 action: 1, total_reward: 478.0, done:False
# step: 479 action: 0, total_reward: 479.0, done:False
# step: 480 action: 1, total_reward: 480.0, done:False
# step: 481 action: 1, total_reward: 481.0, done:False
# step: 482 action: 0, total_reward: 482.0, done:False
# step: 483 action: 1, total_reward: 483.0, done:False
# step: 484 action: 0, total_reward: 484.0, done:False
# step: 485 action: 0, total_reward: 485.0, done:False
# step: 486 action: 1, total_reward: 486.0, done:False
# step: 487 action: 0, total_reward: 487.0, done:False
# step: 488 action: 1, total_reward: 488.0, done:False
# step: 489 action: 0, total_reward: 489.0, done:False
# step: 490 action: 1, total_reward: 490.0, done:False
# step: 491 action: 1, total_reward: 491.0, done:False
# step: 492 action: 0, total_reward: 492.0, done:False
# step: 493 action: 1, total_reward: 493.0, done:False
# step: 494 action: 0, total_reward: 494.0, done:False
# step: 495 action: 1, total_reward: 495.0, done:False
# step: 496 action: 0, total_reward: 496.0, done:False
# step: 497 action: 1, total_reward: 497.0, done:False
# step: 498 action: 0, total_reward: 498.0, done:False
# step: 499 action: 0, total_reward: 499.0, done:False
# step: 500 action: 1, total_reward: 500.0, done:True

# %%
state = env.reset()
prob = agentoo7.model(tf.reshape(state, [-1, 4]))
action = tf.math.argmax(prob, axis=1)
state, prob, action
# Out:
# (array([ 0.00261727, -0.03078178, -0.01598616,  0.00459414], dtype=float32),
#  <tf.Tensor: shape=(1, 2), dtype=float32, numpy=array([[0.49441344, 0.5055866 ]], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=int64, numpy=array([1])>)

# %%
dist = tfp.distributions.Categorical(probs=prob, dtype=tf.float32)
log_prob = dist.log_prob(action)
#loss = -log_prob*reward
prob, action, log_prob
# Out:
# (<tf.Tensor: shape=(1, 2), dtype=float32, numpy=array([[0.49441344, 0.5055866 ]], dtype=float32)>,
#  1,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([-0.6820359], dtype=float32)>)

# %%
dist.logits_parameter()
# Out:
# <tf.Tensor: shape=(1, 2), dtype=float32, numpy=array([[-0.7043832 , -0.68203586]], dtype=float32)>

# %%
tf.math.log(prob)
# Out:
# <tf.Tensor: shape=(1, 2), dtype=float32, numpy=array([[-0.7043832 , -0.68203586]], dtype=float32)>

# %%
# action = agentoo7.act(state)
# action

# %%
# prob = agentoo7.model(tf.reshape(state, [-1, 4]))
# prob

# %%
# dist = tfp.distributions.Categorical(probs=prob, dtype=tf.float32)

# %%
# dist.sample()
